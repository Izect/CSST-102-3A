# %% [markdown]
# <a href="https://colab.research.google.com/github/Izect/CSST-102-3A/blob/main/3A_TEA%C3%91O_MP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('/content/datasets_house_prices.csv')

# %%
print(df.head(50))
# Out:
#     Size (sqft)  Bedrooms  Age  Proximity to Downtown (miles)         Price
# 0          3974         1   97                       2.032719  1.162771e+06
# 1          1660         5   88                      23.695207  4.900021e+05
# 2          2094         4   49                       6.440232  6.400737e+05
# 3          1930         2   28                       8.129315  5.637881e+05
# 4          1895         1   56                       5.358837  5.651289e+05
# 5          3892         1   38                      10.241344  1.170138e+06
# 6          2438         2   94                      22.824169  6.885504e+05
# 7          2969         4   55                      15.821883  8.747031e+05
# 8          1266         1   42                       6.543998  3.800326e+05
# 9          2038         1   49                      26.395987  5.829190e+05
# 10         1130         5   22                      26.447665  3.386671e+05
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
sns.scatterplot(ax=axes[0], x='Size (sqft)', y='Price', data=df)

axes[0].set_title('Size vs Price')
sns.scatterplot(ax=axes[1], x='Age', y='Price', data=df)

axes[1].set_title('Age vs Price')
sns.scatterplot(ax=axes[2], x='Proximity to Downtown (miles)',
                y='Price', data=df)
axes[2].set_title('Proximity to Downtown vs Price')

plt.tight_layout()
plt.show()

# %%
print(df.isnull().sum())
# Out:
# Size (sqft)                      0
# Bedrooms                         0
# Age                              0
# Proximity to Downtown (miles)    0
# Price                            0
# dtype: int64

# %%
features = ['Size (sqft)', 'Bedrooms', 'Age', 'Proximity to Downtown (miles)']
X = df[features]
y = df['Price']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 100214724.63128743
# R-squared: 0.9986314443568995

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r', lw=2)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Predicted vs Actual Prices')
plt.show()

# %%
coefficients = pd.DataFrame(model.coef_, features, columns=['Coefficient'])
print(coefficients)
# Out:
#                                  Coefficient
# Size (sqft)                    278975.285938
# Bedrooms                         6804.519001
# Age                             -6082.939258
# Proximity to Downtown (miles)   -8459.853956

# %%
tt

# %% [markdown]
# *Report*
#
# The steps taken were as follows:
# Data preprocessing was  handled first with data loading, handling missing data, etc. Then i moved on to MOdel development and split the data into 70/30 split and used scikits-learn Linear Regression. Then used feature selection.
# afterwards came the model evaluation where i evaluated the model using MSE and R squared and used plots for visualization while the coefficients were used to interpret the significance of each feature
#
# ***Visualizations***
#
# **Scatter plot**
#
# **Correlation Matrix**
#
# **Predicted v Actual Price Plot**
#
# Conclusion the model predicted the house prices based on given features however additional data could be used to increase the accuracy so that this can be applied in a real world scenario.
